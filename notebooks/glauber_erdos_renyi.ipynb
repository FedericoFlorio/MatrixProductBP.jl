# %% [markdown]
# # Glauber on infinite Erdos-Renyi graph
# Compute magnetization in the thermodynamic limit $N\to\infty$ for Erdos-Renyi graphs with average connectivity $c=4$ using population dynamics.

# %%
using MatrixProductBP, MatrixProductBP.Models
using TensorTrains
using Distributions, Statistics, Base.Threads, Plots, LaTeXStrings
using ProgressMeter; ProgressMeter.ijulia_behavior(:clear)
using JLD2;
# Out:
# WARNING: using Nemo.weights in module MatrixProductBP conflicts with an existing identifier.
# WARNING: could not import CavityTools.ExponentialQueue into MatrixProductBP

# %%
T = 15      # final time
c = 4.0     # average degree
m⁰ = -0.6   # magnetization at time zero

β = 1.0
J = 0.5
h = 0.0

popsize = 10^2              # population size
svd_trunc = TruncBond(18);  # SVD truncator

# %%
wᵢ = fill(HomogeneousGlauberFactor(J, h, β), T+1)
ϕᵢ = [ t == 0 ? [(1+m⁰)/2, (1-m⁰)/2] : ones(2) for t in 0:T]
ψ_neutral = [ones(2,2) for t in 0:T];

# %%
function onebpiter_inner(μ, wᵢ, dᵢ, ns, ϕᵢ, ψ, T, svd_trunc)
    C, full, _ = MatrixProductBP.compute_prob_ys(wᵢ, ns, μ, ψ, T, svd_trunc)
    logzᵢ = 0.0
    for j in 1:dᵢ
        B = MatrixProductBP.f_bp_partial_ij(C[j], wᵢ, ϕᵢ, dᵢ - 1, ns, j)
        μ[j] = orthogonalize_right!(mpem2(B); svd_trunc)
        logzᵢ += normalize!(μ[j])
    end
    B = MatrixProductBP.f_bp_partial_i(full, wᵢ, ϕᵢ, dᵢ)
    b = B |> mpem2 |> marginalize
    f = dᵢ == 0 ? 0.0 : -logzᵢ / dᵢ
    return μ, b, f
end
# Out:
# onebpiter_inner (generic function with 1 method)

# %%
function iterate_population!(P, bs, btus, wᵢ, degree_prob, ϕᵢ, T, svd_trunc; nsamples=10^2)
    @showprogress for n in 1:nsamples
        d = rand(degree_prob)
        d > popsize && error("Sampled degree $d greater than population size $popsize")
        indices = rand(eachindex(P), d)     
        μ, b, f = onebpiter_inner(P[indices], wᵢ, d, 2, ϕᵢ, fill(ψ_neutral, d), T, svd_trunc)
        P[indices] = μ
        push!(bs, marginals(b))
        push!(btus, twovar_marginals(b))
    end
end
# Out:
# iterate_population! (generic function with 1 method)

# %%
degree_prob = Poisson(c)
P = map(1:popsize) do p
    μ = rand_mpem2(2, 2, T)
    normalize!(μ)
    μ
end
bs = Vector{Vector{Float64}}[]
btus =  Matrix{Matrix{Float64}}[];

# %%
iterate_population!(P, bs, btus, wᵢ, degree_prob, ϕᵢ, T, svd_trunc; nsamples=3*10^3);
# Out:
# Progress:   0%|▏                                        |  ETA: 1 days, 7:08:01K
# InterruptException:
#
#
#
# Stacktrace:
#
#   [1] norm(itr::Vector{Float64}, p::Int64)
#
#     @ LinearAlgebra ~/.julia/juliaup/julia-1.11.5+0.x64.linux.gnu/share/julia/stdlib/v1.11/LinearAlgebra/src/generic.jl:601
#
#   [2] norm
#
#     @ ~/.julia/juliaup/julia-1.11.5+0.x64.linux.gnu/share/julia/stdlib/v1.11/LinearAlgebra/src/generic.jl:602 [inlined]
#
#   [3] (::TruncThresh{Float64})(M::Matrix{Float64})
#
#     @ TensorTrains ~/src/TensorTrains.jl/src/svd_trunc.jl:38
#
#   [4] orthogonalize_right!(C::TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}; svd_trunc::TruncThresh{Float64})
#
#     @ TensorTrains ~/src/TensorTrains.jl/src/tensor_train.jl:89
#
#   [5] orthogonalize_right!
#
#     @ ~/src/TensorTrains.jl/src/tensor_train.jl:81 [inlined]
#
#   [6] compress!(A::TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}; svd_trunc::TruncBond, is_orthogonal::Symbol)
#
#     @ TensorTrains ~/src/TensorTrains.jl/src/abstract_tensor_train.jl:233
#
#   [7] compress!
#
#     @ ~/src/TensorTrains.jl/src/abstract_tensor_train.jl:230 [inlined]
#
#   [8] (::MatrixProductBP.var"#op#288"{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Vector{HomogeneousGlauberFactor{Float64}}, TruncBond})(::Tuple{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Int64}, ::Tuple{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Int64})
#
#     @ MatrixProductBP ~/src/MatrixProductBP.jl/src/recursive_bp_factor.jl:125
#
#   [9] cavity!(dest::Vector{Tuple{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Int64}}, source::Vector{Tuple{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Int64}}, op::MatrixProductBP.var"#op#288"{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Vector{HomogeneousGlauberFactor{Float64}}, TruncBond}, init::Tuple{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}, Int64})
#
#     @ CavityTools ~/.julia/packages/CavityTools/0l9BS/src/cavity.jl:51
#
#  [10] cavity
#
#     @ ~/.julia/packages/CavityTools/0l9BS/src/cavity.jl:60 [inlined]
#
#  [11] compute_prob_ys(wᵢ::Vector{HomogeneousGlauberFactor{Float64}}, qi::Int64, μin::Vector{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}}, ψout::Vector{Vector{Matrix{Float64}}}, T::Int64, svd_trunc::TruncBond)
#
#     @ MatrixProductBP ~/src/MatrixProductBP.jl/src/recursive_bp_factor.jl:137
#
#  [12] onebpiter_inner(μ::Vector{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}}, wᵢ::Vector{HomogeneousGlauberFactor{Float64}}, dᵢ::Int64, ns::Int64, ϕᵢ::Vector{Vector{Float64}}, ψ::Vector{Vector{Matrix{Float64}}}, T::Int64, svd_trunc::TruncBond)
#
#     @ Main ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W4sdnNjb2RlLXJlbW90ZQ==.jl:2
#
#  [13] macro expansion
#
#     @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sdnNjb2RlLXJlbW90ZQ==.jl:6 [inlined]
#
#  [14] macro expansion
#
#     @ ~/.julia/packages/ProgressMeter/kniaW/src/ProgressMeter.jl:1021 [inlined]
#
#  [15] iterate_population!(P::Vector{TensorTrain{Float64, 4, Array{Float64, 4}, LogarithmicNumbers.LogFloat64}}, bs::Vector{Vector{Vector{Float64}}}, btus::Vector{Matrix{Matrix{Float64}}}, wᵢ::Vector{HomogeneousGlauberFactor{Float64}}, degree_prob::Poisson{Float64}, ϕᵢ::Vector{Vector{Float64}}, T::Int64, svd_trunc::TruncBond; nsamples::Int64)
#
#     @ Main ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W5sdnNjb2RlLXJlbW90ZQ==.jl:2
#
#  [16] top-level scope
#
#     @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sdnNjb2RlLXJlbW90ZQ==.jl:1

# %%
spin(x) = 3 - 2x
# take the average beliefs over the last `ns` iterations
ns = 1000
range = length(btus)+1-min(ns, length(btus)):length(btus)
ms = [expectation.(spin, b) for b in bs[range]]
m_avg = mean(ms)
m_std = std(ms) ./ sqrt(length(ms));
# Out:
# MethodError: no method matching zero(::Type{Vector{Float64}})
#
# The function `zero` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   zero(!Matched::Type{Union{}}, Any...)
#
#    @ Base number.jl:310
#
#   zero(!Matched::Type{Dates.Date})
#
#    @ Dates ~/.julia/juliaup/julia-1.11.5+0.x64.linux.gnu/share/julia/stdlib/v1.11/Dates/src/types.jl:459
#
#   zero(!Matched::Type{IndexedGraphs.NullNumber})
#
#    @ IndexedGraphs ~/.julia/packages/IndexedGraphs/rBQgK/src/utils.jl:59
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#   [1] reduce_empty(::typeof(+), ::Type{Vector{Float64}})
#
#     @ Base ./reduce.jl:343
#
#   [2] reduce_empty(::typeof(Base.add_sum), ::Type{Vector{Float64}})
#
#     @ Base ./reduce.jl:350
#
#   [3] mapreduce_empty(::typeof(identity), op::Function, T::Type)
#
#     @ Base ./reduce.jl:369
#
#   [4] reduce_empty(op::Base.MappingRF{typeof(identity), typeof(Base.add_sum)}, ::Type{Vector{Float64}})
#
#     @ Base ./reduce.jl:358
#
#   [5] reduce_empty_iter
#
#     @ ./reduce.jl:381 [inlined]
#
#   [6] mapreduce_empty_iter(f::Function, op::Function, itr::Vector{Vector{Float64}}, ItrEltype::Base.HasEltype)
#
#     @ Base ./reduce.jl:377
#
#   [7] _mapreduce(f::typeof(identity), op::typeof(Base.add_sum), ::IndexLinear, A::Vector{Vector{Float64}})
#
#     @ Base ./reduce.jl:429
#
#   [8] _mapreduce_dim
#
#     @ ./reducedim.jl:337 [inlined]
#
#   [9] mapreduce
#
#     @ ./reducedim.jl:329 [inlined]
#
#  [10] _sum
#
#     @ ./reducedim.jl:987 [inlined]
#
#  [11] sum
#
#     @ ./reducedim.jl:983 [inlined]
#
#  [12] _mean(f::typeof(identity), A::Vector{Vector{Float64}}, dims::Colon)
#
#     @ Statistics ~/.julia/packages/Statistics/gbcbG/src/Statistics.jl:184
#
#  [13] mean(A::Vector{Vector{Float64}})
#
#     @ Statistics ~/.julia/packages/Statistics/gbcbG/src/Statistics.jl:178
#
#  [14] top-level scope
#
#     @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X11sdnNjb2RlLXJlbW90ZQ==.jl:6

# %%
spin(x) = 3 - 2x
rs = [expectation.(spin, btu) for btu in btus[range]]
cs = MatrixProductBP.covariance.(rs, ms)
c_avg = mean(cs)
c_std = std(cs) ./ sqrt(length(cs));
# Out:
# MethodError: no method matching zero(::Type{Matrix{Float64}})
#
# The function `zero` exists, but no method is defined for this combination of argument types.
#
#
#
# Closest candidates are:
#
#   zero(!Matched::Type{Union{}}, Any...)
#
#    @ Base number.jl:310
#
#   zero(!Matched::Type{Dates.Date})
#
#    @ Dates ~/.julia/juliaup/julia-1.11.5+0.x64.linux.gnu/share/julia/stdlib/v1.11/Dates/src/types.jl:459
#
#   zero(!Matched::Type{IndexedGraphs.NullNumber})
#
#    @ IndexedGraphs ~/.julia/packages/IndexedGraphs/rBQgK/src/utils.jl:59
#
#   ...
#
#
#
#
#
# Stacktrace:
#
#   [1] reduce_empty(::typeof(+), ::Type{Matrix{Float64}})
#
#     @ Base ./reduce.jl:343
#
#   [2] reduce_empty(::typeof(Base.add_sum), ::Type{Matrix{Float64}})
#
#     @ Base ./reduce.jl:350
#
#   [3] mapreduce_empty(::typeof(identity), op::Function, T::Type)
#
#     @ Base ./reduce.jl:369
#
#   [4] reduce_empty(op::Base.MappingRF{typeof(identity), typeof(Base.add_sum)}, ::Type{Matrix{Float64}})
#
#     @ Base ./reduce.jl:358
#
#   [5] reduce_empty_iter
#
#     @ ./reduce.jl:381 [inlined]
#
#   [6] mapreduce_empty_iter(f::Function, op::Function, itr::Vector{Matrix{Float64}}, ItrEltype::Base.HasEltype)
#
#     @ Base ./reduce.jl:377
#
#   [7] _mapreduce(f::typeof(identity), op::typeof(Base.add_sum), ::IndexLinear, A::Vector{Matrix{Float64}})
#
#     @ Base ./reduce.jl:429
#
#   [8] _mapreduce_dim
#
#     @ ./reducedim.jl:337 [inlined]
#
#   [9] mapreduce
#
#     @ ./reducedim.jl:329 [inlined]
#
#  [10] _sum
#
#     @ ./reducedim.jl:987 [inlined]
#
#  [11] sum
#
#     @ ./reducedim.jl:983 [inlined]
#
#  [12] _mean(f::typeof(identity), A::Vector{Matrix{Float64}}, dims::Colon)
#
#     @ Statistics ~/.julia/packages/Statistics/gbcbG/src/Statistics.jl:184
#
#  [13] mean(A::Vector{Matrix{Float64}})
#
#     @ Statistics ~/.julia/packages/Statistics/gbcbG/src/Statistics.jl:178
#
#  [14] top-level scope
#
#     @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X12sdnNjb2RlLXJlbW90ZQ==.jl:4

# %%
plot_autocovs(args...; kw...) = plot_autocovs!(plot(), args...; kw...)
function plot_autocovs!(pl, c; skip_even=false, T=size(c,1)-1, us = 0:(2*floor(Int, T/10)):T, kw...)
    step = skip_even ? 2 : 1
    cg = cgrad(:matter, length(us)+1, categorical=true)
    ylabel = L"\langle x_{i}^t x_{i}^{t+\Delta t}\rangle-" * 
        L"\langle x_{i}^t\rangle\langle x_{i}^{t+\Delta t}\rangle"
    xlabel = L"\Delta t"
    plot!(pl; xlabel, ylabel, legend=:outertopright)
     
    for (j,u) in enumerate(us)
        plot!(pl, u:-step:1, c[(0:step:u-1) .+ 1,u+1], label="t+Δt=$u", c=cg[j+1], msc=:auto; kw...) 
    end
    pl
end 

plot_autocovs(c_avg; skip_even=true, yaxis=:log10, m=:o, us=4:2:T)
# Out:
# UndefVarError: `c_avg` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X13sdnNjb2RlLXJlbW90ZQ==.jl:16

# %%
using Graphs, IndexedGraphs

seed = 1
N = 5*10^3
g = erdos_renyi(N, c/N; seed)
ising = Ising(IndexedGraph(g); J=fill(J, ne(g)), h=fill(h, N), β)
bp = mpbp(Glauber(ising, T); ϕ = fill(ϕᵢ, N))
sms = SoftMarginSampler(bp);

# %%
sample!(sms, 5*10^3)
m_mc = [vec(spin.(mean(X, dims=1))) for X in sms.X];
# Out:
# SoftMargin sampling 100%|████████████████████████████████| Time: 0:08:08

# %%
m_eq = equilibrium_magnetization(ErdosRenyi(c); pJ=Dirac(J), β, ph=Dirac(h), popsize=2*10^6,
        maxiter=10^2, tol=1e-6, nsamples=10^4);
# Out:
# Running PopDyn: iter 2    Time: 0:00:06
#
# Running PopDyn: iter 3    Time: 0:00:08
#
# Running PopDyn: iter 4    Time: 0:00:11
#
# Running PopDyn: iter 5    Time: 0:00:13
#
# Running PopDyn: iter 6    Time: 0:00:15
#
# Running PopDyn: iter 7    Time: 0:00:18
#
# Running PopDyn: iter 8    Time: 0:00:20
#
# Running PopDyn: iter 9    Time: 0:00:22
#
# Running PopDyn: iter 10    Time: 0:00:25
#
# Running PopDyn: iter 11    Time: 0:00:27
#
# Running PopDyn: iter 12    Time: 0:00:29
#
# Running PopDyn: iter 13    Time: 0:00:31
#
# Running PopDyn: iter 14    Time: 0:00:34
#
# Running PopDyn: iter 15    Time: 0:00:36
#
# Running PopDyn: iter 16    Time: 0:00:38
#
# Running PopDyn: iter 17    Time: 0:00:41
#
# Running PopDyn: iter 18    Time: 0:00:43
#
# Running PopDyn: iter 19    Time: 0:00:46
#
# Running PopDyn: iter 20    Time: 0:00:48
#
# Running PopDyn: iter 21    Time: 0:00:50
#
# Running PopDyn: iter 22    Time: 0:00:53
#
# Running PopDyn: iter 23    Time: 0:00:55
#
# Running PopDyn: iter 24    Time: 0:00:57
#
# Running PopDyn: iter 25    Time: 0:01:00
#
# Running PopDyn: iter 26    Time: 0:01:02
#
# Running PopDyn: iter 27    Time: 0:01:04
#
# Running PopDyn: iter 28    Time: 0:01:07
#
# Running PopDyn: iter 29    Time: 0:01:09
#
# Running PopDyn: iter 30    Time: 0:01:11
#
# Running PopDyn: iter 31    Time: 0:01:14
#
# Running PopDyn: iter 32    Time: 0:01:16
#
# Running PopDyn: iter 33    Time: 0:01:18
#
# Running PopDyn: iter 34    Time: 0:01:21
#
# Running PopDyn: iter 35    Time: 0:01:23
#
# Running PopDyn: iter 36    Time: 0:01:25
#
# Running PopDyn: iter 37    Time: 0:01:28
#
# Running PopDyn: iter 38    Time: 0:01:30
#
# Running PopDyn: iter 39    Time: 0:01:32
#
# Running PopDyn: iter 40    Time: 0:01:35
#
# Running PopDyn: iter 41    Time: 0:01:37
#
# Running PopDyn: iter 42    Time: 0:01:40
#
# Running PopDyn: iter 43    Time: 0:01:42
#
# Running PopDyn: iter 44    Time: 0:01:44
#
# Running PopDyn: iter 45    Time: 0:01:47
#
# Running PopDyn: iter 46    Time: 0:01:49
#
# Running PopDyn: iter 47    Time: 0:01:51
#
# Running PopDyn: iter 48    Time: 0:01:54
#
# Running PopDyn: iter 49    Time: 0:01:56
#
# Running PopDyn: iter 50    Time: 0:01:58
#
# Running PopDyn: iter 51    Time: 0:02:01
#
# Running PopDyn: iter 52    Time: 0:02:03
#
# Running PopDyn: iter 53    Time: 0:02:06
#
# Running PopDyn: iter 54    Time: 0:02:08
#
# Running PopDyn: iter 55    Time: 0:02:10
#
# Running PopDyn: iter 56    Time: 0:02:13
#
# Running PopDyn: iter 57    Time: 0:02:15
#
# Running PopDyn: iter 58    Time: 0:02:17
#
# Running PopDyn: iter 59    Time: 0:02:20
#
# Running PopDyn: iter 60    Time: 0:02:22
#
# Running PopDyn: iter 61    Time: 0:02:25
#
# Running PopDyn: iter 62    Time: 0:02:27
#
# Running PopDyn: iter 63    Time: 0:02:29
#
# Running PopDyn: iter 64    Time: 0:02:32
#
# Running PopDyn: iter 65    Time: 0:02:34
#
# Running PopDyn: iter 66    Time: 0:02:36
#
# Running PopDyn: iter 67    Time: 0:02:39
#
# Running PopDyn: iter 68    Time: 0:02:41
#
# Running PopDyn: iter 69    Time: 0:02:43
#
# Running PopDyn: iter 70    Time: 0:02:46
#
# Running PopDyn: iter 71    Time: 0:02:48
#
# Running PopDyn: iter 72    Time: 0:02:51
#
# Running PopDyn: iter 73    Time: 0:02:53
#
# Running PopDyn: iter 74    Time: 0:02:55
#
# Running PopDyn: iter 75    Time: 0:02:58
#
# Running PopDyn: iter 76    Time: 0:03:00
#
# Running PopDyn: iter 77    Time: 0:03:03
#
# Running PopDyn: iter 78    Time: 0:03:05
#
# Running PopDyn: iter 79    Time: 0:03:07
#
# Running PopDyn: iter 80    Time: 0:03:10
#
# Running PopDyn: iter 81    Time: 0:03:12
#
# Running PopDyn: iter 82    Time: 0:03:15
#
# Running PopDyn: iter 83    Time: 0:03:17
#
# Running PopDyn: iter 84    Time: 0:03:19
#
# Running PopDyn: iter 85    Time: 0:03:22
#
# Running PopDyn: iter 86    Time: 0:03:24
#
# Running PopDyn: iter 87    Time: 0:03:27
#
# Running PopDyn: iter 88    Time: 0:03:29
#
# Running PopDyn: iter 89    Time: 0:03:31
#
# Running PopDyn: iter 90    Time: 0:03:34
#
# Running PopDyn: iter 91    Time: 0:03:36
#
# Running PopDyn: iter 92    Time: 0:03:39
#
# Running PopDyn: iter 93    Time: 0:03:41
#
# Running PopDyn: iter 94    Time: 0:03:43
#
# Running PopDyn: iter 95    Time: 0:03:46
#
# Running PopDyn: iter 96    Time: 0:03:48
#
# Running PopDyn: iter 97    Time: 0:03:51
#
# Running PopDyn: iter 98    Time: 0:03:53
#
# Running PopDyn: iter 99    Time: 0:03:55
#
# Running PopDyn: iter 100    Time: 0:03:58┌ Warning: Population dynamics did not converge. Error 0.002018462300056534
# └ @ MatrixProductBP.Models /home/disat/fflorio/src/MatrixProductBP.jl/src/Models/glauber/equilibrium.jl:113

# %%
pl = plot(0:T, m_avg, lw=3, ribbon=m_std, xlabel="time", ylabel="magnetiz",
    title="Glauber on infinite Erdos-Renyi with average degree $(Int(c))", titlefontsize=12,
    size = (600,300), label="MPBP")
pl2 = deepcopy(pl)
scatter!(pl2, 0:T, mean(m_mc), label="MC", c=:black, m=:diamond)
pl3 = deepcopy(pl2)
hline!(pl3, [-m_eq.val], label="equilibrium", c=:red, ls=:dash, lw=1, size=(600,300)#=, ribbon=[-m_eq.err]=#)
# Out:
# UndefVarError: `m_std` not defined in `Main`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/src/MatrixProductBP.jl/notebooks/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X20sdnNjb2RlLXJlbW90ZQ==.jl:1

# %%
# jldsave("plot_data/glauber_erdos_renyi.jld2"; T, m_mc, m_avg, m_std, m_eq, c_avg, c_std);
